# %%
import requests
from bs4 import BeautifulSoup
import selenium
from flask import jsonify
from config import key
from pprint import pprint
import json
from getdata import getdata

# %%
getdata()
# Out:
# ('{\n'
#  '   "status":"OK",\n'
#  '   "copyright":"Copyright (c) 2023 Pro Publica Inc. All Rights Reserved.",\n'
#  '   "results":[\n'
#  '      {\n'
#  '         \n'
#  '         \n'
#  '         "num_results": 20,\n'
#  '         "offset": 0,\n'
#  '         "bills": [\n'
#  '              {\n'
#  '                 "bill_id": "hres223-118",\n'
#  '                 "bill_slug": "hres223",\n'
#  '                 "bill_type": "hres",\n'
#  '                 "number": "H.RES.223",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hres223.json",\n'
#  '                 "title": "Recognizing the significance of Atlanta, Georgia, '
#  'as the cradle of the civil rights movement.",\n'
#  '                 "short_title": "Recognizing the significance of Atlanta, '
#  'Georgia, as the cradle of the civil rights movement.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "S001157",\n'
#  '                 "sponsor_name": "David Scott",\n'
#  '                 "sponsor_state": "GA",\n'
#  '                 "sponsor_party": "D",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/S001157.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-resolution/223",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hres223",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 5,\n'
#  '                 "cosponsors_by_party": {"D":5},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSJU"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'the Judiciary."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hres221-118",\n'
#  '                 "bill_slug": "hres221",\n'
#  '                 "bill_type": "hres",\n'
#  '                 "number": "H.RES.221",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hres221.json",\n'
#  '                 "title": "Expressing support for designation of March 14, '
#  '2023, as \\"National Pi Day\\".",\n'
#  '                 "short_title": "Expressing support for designation of March '
#  '14, 2023, as \\"National Pi Day\\".",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "F000454",\n'
#  '                 "sponsor_name": "Bill Foster",\n'
#  '                 "sponsor_state": "IL",\n'
#  '                 "sponsor_party": "D",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/F000454.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-resolution/221",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hres221",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 12,\n'
#  '                 "cosponsors_by_party": {"D":11,"R":1},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSSY"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Science, Space, and Technology."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1557-118",\n'
#  '                 "bill_slug": "hr1557",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1557",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1557.json",\n'
#  '                 "title": "To require the Secretary of Health and Human '
#  'Services to submit a report on the interoperability of medical devices.",\n'
#  '                 "short_title": "To require the Secretary of Health and '
#  'Human Services to submit a report on the interoperability of medical '
#  'devices.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "M001215",\n'
#  '                 "sponsor_name": "Mariannette Miller-Meeks",\n'
#  '                 "sponsor_state": "IA",\n'
#  '                 "sponsor_party": "R",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/M001215.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1557",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1557",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 3,\n'
#  '                 "cosponsors_by_party": {"D":2,"R":1},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSIF"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Energy and Commerce."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1566-118",\n'
#  '                 "bill_slug": "hr1566",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1566",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1566.json",\n'
#  '                 "title": "To permit employees of the House of '
#  'Representatives who are authorized to possess certain weapons in the '
#  'District of Columbia to bring such weapons into House Office Buildings for '
#  'secure storage, and for other purposes.",\n'
#  '                 "short_title": "To permit employees of the House of '
#  'Representatives who are authorized to possess certain weapons in the '
#  'District of Columbia to bring such weapons into House Office Buildings for '
#  'secure storage, and for other purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "S001214",\n'
#  '                 "sponsor_name": "Greg Steube",\n'
#  '                 "sponsor_state": "FL",\n'
#  '                 "sponsor_party": "R",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/S001214.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1566",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1566",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 0,\n'
#  '                 "cosponsors_by_party": {},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSHA"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the Committee on House '
#  'Administration, and in addition to the Committee on Transportation and '
#  'Infrastructure, for a period to be subsequently determined by the Speaker, '
#  'in each case for consideration of such provisions as fall within the '
#  'jurisdiction of the committee concerned."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1544-118",\n'
#  '                 "bill_slug": "hr1544",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1544",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1544.json",\n'
#  '                 "title": "To adjust the boundary of Big Bend National Park '
#  'in the State of Texas, and for other purposes.",\n'
#  '                 "short_title": "To adjust the boundary of Big Bend National '
#  'Park in the State of Texas, and for other purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "G000594",\n'
#  '                 "sponsor_name": "Tony Gonzales",\n'
#  '                 "sponsor_state": "TX",\n'
#  '                 "sponsor_party": "R",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/G000594.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1544",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1544",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 0,\n'
#  '                 "cosponsors_by_party": {},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSII"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Natural Resources."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1543-118",\n'
#  '                 "bill_slug": "hr1543",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1543",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1543.json",\n'
#  '                 "title": "To direct the Secretary of Labor to ensure that '
#  'the database relating to investigations under the Fair Labor Standards Act '
#  'of 1938 is language accessible, and for other purposes.",\n'
#  '                 "short_title": "To direct the Secretary of Labor to ensure '
#  'that the database relating to investigations under the Fair Labor Standards '
#  'Act of 1938 is language accessible, and for other purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "G000587",\n'
#  '                 "sponsor_name": "Sylvia Garcia",\n'
#  '                 "sponsor_state": "TX",\n'
#  '                 "sponsor_party": "D",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/G000587.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1543",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1543",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 7,\n'
#  '                 "cosponsors_by_party": {"D":7},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSED"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Education and the Workforce."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1569-118",\n'
#  '                 "bill_slug": "hr1569",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1569",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1569.json",\n'
#  '                 "title": "To prohibit the Secretary of the Interior from '
#  'issuing leases to certain entities affiliated with the Chinese Communist '
#  'Party, and for other purposes.",\n'
#  '                 "short_title": "To prohibit the Secretary of the Interior '
#  'from issuing leases to certain entities affiliated with the Chinese '
#  'Communist Party, and for other purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "W000823",\n'
#  '                 "sponsor_name": "Michael Waltz",\n'
#  '                 "sponsor_state": "FL",\n'
#  '                 "sponsor_party": "R",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/W000823.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1569",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1569",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 2,\n'
#  '                 "cosponsors_by_party": {"D":1,"R":1},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSII"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the Committee on '
#  'Natural Resources, and in addition to the Committee on Agriculture, for a '
#  'period to be subsequently determined by the Speaker, in each case for '
#  'consideration of such provisions as fall within the jurisdiction of the '
#  'committee concerned."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1539-118",\n'
#  '                 "bill_slug": "hr1539",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1539",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1539.json",\n'
#  '                 "title": "To amend the Richard B. Russell National School '
#  'Lunch Act to require schools to provide fluid milk substitutes upon request '
#  'of a student or the parent or guardian of such student, and for other '
#  'purposes.",\n'
#  '                 "short_title": "To amend the Richard B. Russell National '
#  'School Lunch Act to require schools to provide fluid milk substitutes upon '
#  'request of a student or the parent or guardian of such student, and for '
#  'other purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "C001125",\n'
#  '                 "sponsor_name": "Troy Carter",\n'
#  '                 "sponsor_state": "LA",\n'
#  '                 "sponsor_party": "D",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/C001125.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1539",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1539",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 0,\n'
#  '                 "cosponsors_by_party": {},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSED"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Education and the Workforce."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1540-118",\n'
#  '                 "bill_slug": "hr1540",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1540",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1540.json",\n'
#  '                 "title": "To establish a means-tested assistance program '
#  'for national flood insurance program policyholders, and for other '
#  'purposes.",\n'
#  '                 "short_title": "To establish a means-tested assistance '
#  'program for national flood insurance program policyholders, and for other '
#  'purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "C001090",\n'
#  '                 "sponsor_name": "Matt Cartwright",\n'
#  '                 "sponsor_state": "PA",\n'
#  '                 "sponsor_party": "D",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/C001090.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1540",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1540",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 0,\n'
#  '                 "cosponsors_by_party": {},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSBA"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Financial Services."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1552-118",\n'
#  '                 "bill_slug": "hr1552",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1552",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1552.json",\n'
#  '                 "title": "To amend title 18, United States Code, to require '
#  'affirmative consent from the governing body of certain Indian Tribes for '
#  'jurisdiction to be conferred on the State of Kansas over offenses committed '
#  'on the reservations of such Indian Tribes, and for other purposes.",\n'
#  '                 "short_title": "To amend title 18, United States Code, to '
#  'require affirmative consent from the governing body of certain Indian Tribes '
#  'for jurisdiction to be conferred on the State of Kansas over offenses '
#  'committed on the reservations of such Indian Tribes, and for other",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "L000266",\n'
#  '                 "sponsor_name": "Jake LaTurner",\n'
#  '                 "sponsor_state": "KS",\n'
#  '                 "sponsor_party": "R",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/L000266.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1552",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1552",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 2,\n'
#  '                 "cosponsors_by_party": {"R":1,"D":1},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSJU"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'the Judiciary."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hres219-118",\n'
#  '                 "bill_slug": "hres219",\n'
#  '                 "bill_type": "hres",\n'
#  '                 "number": "H.RES.219",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hres219.json",\n'
#  '                 "title": "Expressing support for developing supportive, '
#  'inclusive, safe, and responsive public schools that provide all students '
#  'with a well-rounded education and prepare all students for success in life '
#  'and for the exercise of their social and economic rights, fostering parental '
#  'involvement in education in a manner that builds partnerships and trust '
#  'between parents and educators, and protecting the civil rights of students '
#  'and families.",\n'
#  '                 "short_title": "Expressing support for developing '
#  'supportive, inclusive, safe, and responsive public schools that provide all '
#  'students with a well-rounded education and prepare all students for success '
#  'in life and for the exercise of their social and economic rights, fos",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "B001278",\n'
#  '                 "sponsor_name": "Suzanne Bonamici",\n'
#  '                 "sponsor_state": "OR",\n'
#  '                 "sponsor_party": "D",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/B001278.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-resolution/219",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hres219",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 29,\n'
#  '                 "cosponsors_by_party": {"D":29},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSED"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Education and the Workforce."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hres224-118",\n'
#  '                 "bill_slug": "hres224",\n'
#  '                 "bill_type": "hres",\n'
#  '                 "number": "H.RES.224",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hres224.json",\n'
#  '                 "title": "Raising awareness of the racial disparities in '
#  'the impact of colorectal cancer on the Black community.",\n'
#  '                 "short_title": "Raising awareness of the racial disparities '
#  'in the impact of colorectal cancer on the Black community.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "W000822",\n'
#  '                 "sponsor_name": "Bonnie Watson Coleman",\n'
#  '                 "sponsor_state": "NJ",\n'
#  '                 "sponsor_party": "D",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/W000822.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-resolution/224",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hres224",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 7,\n'
#  '                 "cosponsors_by_party": {"D":7},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSIF"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Energy and Commerce."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1570-118",\n'
#  '                 "bill_slug": "hr1570",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1570",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1570.json",\n'
#  '                 "title": "To enhance mental health and psychosocial support '
#  'within United States development and humanitarian assistance programs.",\n'
#  '                 "short_title": "To enhance mental health and psychosocial '
#  'support within United States development and humanitarian assistance '
#  'programs.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "W000826",\n'
#  '                 "sponsor_name": "Susan Wild",\n'
#  '                 "sponsor_state": "PA",\n'
#  '                 "sponsor_party": "D",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/W000826.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1570",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1570",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 6,\n'
#  '                 "cosponsors_by_party": {"R":2,"D":4},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSFA"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Foreign Affairs."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1542-118",\n'
#  '                 "bill_slug": "hr1542",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1542",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1542.json",\n'
#  '                 "title": "To prohibit Secretary of Homeland Security '
#  'Alejandro N. Mayorkas from flying on a Federal executive aircraft.",\n'
#  '                 "short_title": "To prohibit Secretary of Homeland Security '
#  'Alejandro N. Mayorkas from flying on a Federal executive aircraft.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "D000594",\n'
#  '                 "sponsor_name": "Mónica De La Cruz",\n'
#  '                 "sponsor_state": "TX",\n'
#  '                 "sponsor_party": "R",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/D000594.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1542",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1542",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 5,\n'
#  '                 "cosponsors_by_party": {"R":5},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSHM"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Homeland Security."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1541-118",\n'
#  '                 "bill_slug": "hr1541",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1541",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1541.json",\n'
#  '                 "title": "To amend the Small Business Act to include '
#  'requirements relating to apprenticeship program assistance for small '
#  'business development centers, and for other purposes.",\n'
#  '                 "short_title": "To amend the Small Business Act to include '
#  'requirements relating to apprenticeship program assistance for small '
#  'business development centers, and for other purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "C001121",\n'
#  '                 "sponsor_name": "Jason Crow",\n'
#  '                 "sponsor_state": "CO",\n'
#  '                 "sponsor_party": "D",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/C001121.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1541",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1541",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 3,\n'
#  '                 "cosponsors_by_party": {"R":2,"D":1},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSSM"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Small Business."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1538-118",\n'
#  '                 "bill_slug": "hr1538",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1538",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1538.json",\n'
#  '                 "title": "To amend the Small Business Act to provide for '
#  'contracting preferences and other benefits for emerging business '
#  'enterprises, and for other purposes.",\n'
#  '                 "short_title": "To amend the Small Business Act to provide '
#  'for contracting preferences and other benefits for emerging business '
#  'enterprises, and for other purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "C001072",\n'
#  '                 "sponsor_name": "André Carson",\n'
#  '                 "sponsor_state": "IN",\n'
#  '                 "sponsor_party": "D",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/C001072.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1538",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1538",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 7,\n'
#  '                 "cosponsors_by_party": {"D":7},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSSM"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Small Business."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1530-118",\n'
#  '                 "bill_slug": "hr1530",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1530",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1530.json",\n'
#  '                 "title": "To amend title 38, United States Code, to improve '
#  'the requirement to publish disability benefit questionnaire forms of '
#  'Department of Veterans Affairs, and for other purposes.",\n'
#  '                 "short_title": "To amend title 38, United States Code, to '
#  'improve the requirement to publish disability benefit questionnaire forms of '
#  'Department of Veterans Affairs, and for other purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "L000603",\n'
#  '                 "sponsor_name": "Morgan Luttrell",\n'
#  '                 "sponsor_state": "TX",\n'
#  '                 "sponsor_party": "R",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/L000603.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1530",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1530",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 1,\n'
#  '                 "cosponsors_by_party": {"D":1},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSVR"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Veterans\' Affairs."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1531-118",\n'
#  '                 "bill_slug": "hr1531",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1531",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1531.json",\n'
#  '                 "title": "To provide for the renewed availability of funds '
#  'to construct the border wall upon the deployment of the National Guard to '
#  'the southern land border of the United States, and for other purposes.",\n'
#  '                 "short_title": "To provide for the renewed availability of '
#  'funds to construct the border wall upon the deployment of the National Guard '
#  'to the southern land border of the United States, and for other purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "S001220",\n'
#  '                 "sponsor_name": "Dale Strong",\n'
#  '                 "sponsor_state": "AL",\n'
#  '                 "sponsor_party": "R",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/S001220.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1531",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1531",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 0,\n'
#  '                 "cosponsors_by_party": {},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSHM"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Homeland Security."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1553-118",\n'
#  '                 "bill_slug": "hr1553",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1553",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1553.json",\n'
#  '                 "title": "To require the Securities and Exchange Commission '
#  'to revise rules relating to general solicitation or general advertising to '
#  'allow for presentations or other communication made by or on behalf of an '
#  'issuer at certain events, and for other purposes.",\n'
#  '                 "short_title": "To require the Securities and Exchange '
#  'Commission to revise rules relating to general solicitation or general '
#  'advertising to allow for presentations or other communication made by or on '
#  'behalf of an issuer at certain events, and for other purposes.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "L000599",\n'
#  '                 "sponsor_name": "Michael Lawler",\n'
#  '                 "sponsor_state": "NY",\n'
#  '                 "sponsor_party": "R",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/L000599.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1553",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1553",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 1,\n'
#  '                 "cosponsors_by_party": {"D":1},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSBA"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'Financial Services."\n'
#  '              },\n'
#  '                           {\n'
#  '                 "bill_id": "hr1535-118",\n'
#  '                 "bill_slug": "hr1535",\n'
#  '                 "bill_type": "hr",\n'
#  '                 "number": "H.R.1535",\n'
#  '                 "bill_uri": '
#  '"https://api.propublica.org/congress/v1/118/bills/hr1535.json",\n'
#  '                 "title": "To preserve expiring employment-based visas, and '
#  'make them available for issuance during fiscal year 2024.",\n'
#  '                 "short_title": "To preserve expiring employment-based '
#  'visas, and make them available for issuance during fiscal year 2024.",\n'
#  '                 "sponsor_title": "Rep.",\n'
#  '                 "sponsor_id": "B001275",\n'
#  '                 "sponsor_name": "Larry Bucshon",\n'
#  '                 "sponsor_state": "IN",\n'
#  '                 "sponsor_party": "R",\n'
#  '                 "sponsor_uri": '
#  '"https://api.propublica.org/congress/v1/members/B001275.json",\n'
#  '                 "gpo_pdf_uri": null,\n'
#  '                 "congressdotgov_url": '
#  '"https://www.congress.gov/bill/118th-congress/house-bill/1535",\n'
#  '                 "govtrack_url": '
#  '"https://www.govtrack.us/congress/bills/118/hr1535",\n'
#  '                 "introduced_date": "2023-03-10",\n'
#  '                 "active": false,\n'
#  '                 "last_vote": null,\n'
#  '                 "house_passage": null,\n'
#  '                 "senate_passage": null,\n'
#  '                 "enacted": null,\n'
#  '                 "vetoed": null,\n'
#  '                 "cosponsors": 1,\n'
#  '                 "cosponsors_by_party": {"D":1},\n'
#  '                 "committees": "",\n'
#  '                 "committee_codes": ["HSJU"],\n'
#  '                 "subcommittee_codes": [],\n'
#  '                 "primary_subject": "",\n'
#  '                 "summary": "",\n'
#  '                 "summary_short": "",\n'
#  '                 "latest_major_action_date": "2023-03-10",\n'
#  '                 "latest_major_action": "Referred to the House Committee on '
#  'the Judiciary."\n'
#  '              }\n'
#  '             ]\n'
#  '      }\n'
#  '   ]\n'
#  '}\n')
